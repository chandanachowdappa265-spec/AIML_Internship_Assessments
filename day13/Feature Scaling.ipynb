# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.preprocessing import StandardScaler, MinMaxScaler

# %%
import pandas as pd

data = {
    'Age': [20, 21, 22, 27, 30, 35, 40],
    'Salary': [25000, 30000, 50000, 60000, 70000, 120000, 150000]
}

df = pd.DataFrame(data)
df
# Out:
#    Age  Salary
# 0   20   25000
# 1   21   30000
# 2   22   50000
# 3   27   60000
# 4   30   70000
# 5   35  120000
# 6   40  150000

# %%
plt.hist(df['Salary'], bins=5)
plt.title("Salary Before Scaling")
plt.xlabel("Salary")
plt.ylabel("Frequency")
plt.show()

# %%
scaler_standard = StandardScaler()

df_standard = df.copy()
df_standard[['Age', 'Salary']] = scaler_standard.fit_transform(df[['Age', 'Salary']])

df_standard
# Out:
#         Age    Salary
# 0 -1.116191 -1.094240
# 1 -0.974130 -0.978184
# 2 -0.832069 -0.513961
# 3 -0.121766 -0.281850
# 4  0.304416 -0.049738
# 5  1.014719  1.110819
# 6  1.725022  1.807154

# %%
plt.hist(df_standard['Salary'], bins=5)
plt.title("Salary After Standard Scaling")
plt.xlabel("Scaled Salary")
plt.ylabel("Frequency")
plt.show()

# %%
## Apply MinMaxScaler
(Scaled between 0 and 1)
# Out:
#   Cell In[15], line 2
#     (Scaled between 0 and 1)
#      ^
# SyntaxError: invalid syntax. Perhaps you forgot a comma?
